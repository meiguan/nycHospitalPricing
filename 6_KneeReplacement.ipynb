# %% [markdown]
# # About the condition: Arthroplasty Knee
#
# Also known as Knee replacement surgery.
#
# The procedure involves cutting away damaged bone and cartilage from thighbone, shinbone and kneecap and replacing it with an artificial joint (prosthesis) made of metal alloys, high-grade plastics and polymers.

# %% [markdown]
# # About this notebook
#
# **The goal:**
# - conduct some machine learning models.
# - Train test split, see which factors are significant in accounting for the cost of anthroplasty knee surgery cost
#
# **What is the dependent variable?**
# - Avg cost of anthroplasty
#
# **What are the independent variables?**
# - Hospital features
# - etc

# %%
import pandas as pd

# %%
# Reading in the cost data
test = pd.read_csv('~/002_ML/nycHospitalPricing/dataFiles/compiledMasterchargesNycHospitals.csv')
test
# Out:
#        Unnamed: 0                       hospitalName  drgType  facId  \
# 0               0      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 1               1      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 2               2      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 3               3      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 4               4      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 5               5      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 6               6      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 7               7      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 8               8      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 9               9      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 10             10      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 11             11      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 12             12      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 13             13      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 14             14      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 15             15      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 16             16      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 17             17      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 18             18      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 19             19      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 20             20      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 21             21      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 22             22      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 23             23      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 24             24      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 25             25      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 26             26      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 27             27      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 28             28      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# 29             29      BRONX-LEBANON HOSPITAL CENTER  APR-DRG   1164
# ...           ...                                ...      ...    ...
# 96482       96482  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96483       96483  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96484       96484  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96485       96485  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96486       96486  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96487       96487  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96488       96488  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96489       96489  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96490       96490  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96491       96491  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96492       96492  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96493       96493  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96494       96494  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96495       96495  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96496       96496  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96497       96497  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96498       96498  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96499       96499  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96500       96500  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96501       96501  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96502       96502  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96503       96503  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96504       96504  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96505       96505  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96506       96506  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96507       96507  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96508       96508  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96509       96509  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96510       96510  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
# 96511       96511  STATEN ISLAND UNIVERSITY HOSPITAL  Unknown   1740
#
#        providerId  hospDrg                     description       charges
# 0          330009    775.0      ALCOHOL ABUSE & DEPENDENCE  22066.805466
# 1          330009    772.0  ALCOHOL/DRUG DEP W/REHAB DETOX  29814.074395
# 2          330009    198.0  ANGINA PECTORIS & CORON ATHERO  21846.361053
# 3          330009    141.0                          ASTHMA   9181.951122
# 4          330009    753.0               BIPOLAR DISORDERS  44274.231067
# 5          330009    383.0  CELLULITIS/OTH BACT SKN INFCNS  22316.887635
# 6          330009    540.0               CESAREAN DELIVERY  25299.090168
# 7          330009    203.0                      CHEST PAIN  18574.202489
# 8          330009    140.0    CHRONIC OBSTRUCTIVE PULM DIS  13160.971033
# 9          330009    774.0      COCAINE ABUSE & DEPENDENCE  17824.844856
# 10         330009    754.0  DEPRESSIVE EXC MAJ DEPR DISORD  29027.126944
# 11         330009    420.0                        DIABETES  12891.145644
# 12         330009    770.0    DRUG & ALCOHOL ABUSE/DEP/AMA  15625.260407
# 13         330009    194.0                   HEART FAILURE  28371.465886
# 14         330009    463.0    KIDNEY & URINARY TRCT INFCNS  23751.737067
# 15         330009    640.0    NEONATE BWT >2499G NORMAL NB  13275.427838
# 16         330009    249.0   NON-FACT GASTROENT NAUS/VOMIT  10651.771326
# 17         330009    773.0       OPIOID ABUSE & DEPENDENCE  15643.360252
# 18         330009    566.0        OTH ANTEPARTUM DIAGNOSIS  10833.816737
# 19         330009    139.0                 OTHER PNEUMONIA  10738.633457
# 20         330009    750.0                   SCHIZOPHRENIA  56614.787787
# 21         330009     53.0                         SEIZURE  11123.833745
# 22         330009    720.0  SEPTICEMIA & DISSEMINTED INFCN  23825.144799
# 23         330009    816.0  TOXIC EFF NON-MEDICINAL SUBSTN  11459.526028
# 24         330009    560.0                VAGINAL DELIVERY  19638.603977
# 25         330009    225.0                    APPENDECTOMY  31106.927895
# 26         330009    812.0   POISONING OF MEDICINAL AGENTS  23659.650445
# 27         330009    241.0       PEPTIC ULCAER & GASTRITIS  11879.398955
# 28         330009    138.0   BRONCHIOLITIS & RSV PNEUMONIA  18072.348820
# 29         330009    199.0                    HYPERTENTION  23822.276218
# ...           ...      ...                             ...           ...
# 96482      330160      NaN          WHIRLPOOL TREATMENT-OT    128.000000
# 96483      330160      NaN       WHLCHR MGMT TRAIN EA15MIN    172.000000
# 96484      330160      NaN        WITH URETH PRES PRO STUD   3192.000000
# 96485      330160      NaN       WND REPAIR FACE 2.6-20 CM   1243.000000
# 96486      330160      NaN       WND REPS/TR/EXT =< 2.5 CM    555.000000
# 96487      330160      NaN       WND REPS/TR/EXT 2.6-7.5CM    652.000000
# 96488      330160      NaN       WND REPS/TR/EXT7.6-12.5CM    809.000000
# 96489      330160      NaN              WRIGHT STAIN NASAL     17.000000
# 96490      330160      NaN           WRIST  MIN 2 VIEWS-RT    320.000000
# 96491      330160      NaN          WRIST COMP-MIN 3 VW-LT    454.000000
# 96492      330160      NaN                   XR ABDOMEN 2V    302.000000
# 96493      330160      NaN           XR CHEST DECUBITUS BI    183.000000
# 96494      330160      NaN                    XR FB IN EYE    146.000000
# 96495      330160      NaN                    XR HIP 1V RT    221.000000
# 96496      330160      NaN            XRAY BITEWING SINGLE     40.000000
# 96497      330160      NaN         XRAY BITEWING TWO FILMS     68.000000
# 96498      330160      NaN              XRAY CEPHALOMETRIC    210.000000
# 96499      330160      NaN         X-RAY EXAM ENT SPI 1 VW    255.000000
# 96500      330160      NaN       X-RAY EXAM ENT SPI 4/5 VW    710.000000
# 96501      330160      NaN       X-RAY EXAM ENT SPI 6/> VW   1051.000000
# 96502      330160      NaN       XRAY EXM ENT SPINE 2/3 VW    425.000000
# 96503      330160      NaN         XRAY INTRAORAL OCCLUSAL   1242.000000
# 96504      330160      NaN       XRAY INTRAORAL PERIAP ADD     28.000000
# 96505      330160      NaN       XRAY INTRAORAL PERIAP SIN     40.000000
# 96506      330160      NaN                  XRAY PANORAMIC    210.000000
# 96507      330160      NaN       X-RAYS BONE SURVEY INFANT    280.000000
# 96508      330160      NaN       Y CHROMOSOMES MICRODELETI    225.000000
# 96509      330160      NaN                      ZINC BLOOD     71.000000
# 96510      330160      NaN           ZINC TRANSPORTER 8 AB    150.000000
# 96511      330160      NaN                      ZONISAMIDE     63.000000
#
# [96512 rows x 8 columns]

# %%
test[test['hospDrg']==313.0]
# Out:
#        Unnamed: 0                                       hospitalName  \
# 189           189                      BRONX-LEBANON HOSPITAL CENTER
# 420           420                              CONEY ISLAND HOSPITAL
# 730           730                           ELMHURST HOSPITAL CENTER
# 1040         1040                             HARLEM HOSPITAL CENTER
# 1350         1350                              JACOBI MEDICAL CENTER
# 1660         1660                       KINGS COUNTY HOSPITAL CENTER
# 1970         1970             LINCOLN MEDICAL & MENTAL HEALTH CENTER
# 2280         2280                       METROPOLITAN HOSPITAL CENTER
# 15569       15569                       NORTH CENTRAL BRONX HOSPITAL
# 15879       15879          WOODHULL MEDICAL AND MENTAL HEALTH CENTER
# 16249       16249                          INTERFAITH MEDICAL CENTER
# 16740       16740                  BROOKDALE HOSPITAL MEDICAL CENTER
# 17340       17340                          MAIMONIDES MEDICAL CENTER
# 18011       18011                              NYU LANGONE HOSPITALS
# 18644       18644                 RICHMOND UNIVERSITY MEDICAL CENTER
# 19144       19144                   FLUSHING HOSPITAL MEDICAL CENTER
# 19666       19666                    JAMAICA HOSPITAL MEDICAL CENTER
# 20301       20301                          MONTEFIORE MEDICAL CENTER
# 21055       21055                               MOUNT SINAI HOSPITAL
# 21766       21766                                   MOUNT SINAI WEST
# 22444       22444  NEW YORK-PRESBYTERIAN BROOKLYN METHODIST HOSPITAL
# 23174       23174                     NEW YORK-PRESBYTERIAN HOSPITAL
# 23906       23906                       NEW YORK-PRESBYTERIAN/QUEENS
# 24580       24580                             QUEENS HOSPITAL CENTER
# 25171       25171      UNIVERSITY HOSPITAL OF BROOKLYN ( DOWNSTATE )
#
#            drgType  facId  providerId  hospDrg  \
# 189        APR-DRG   1164      330009    313.0
# 420        APR-DRG   1294      330196    313.0
# 730        APR-DRG   1626      330128    313.0
# 1040       APR-DRG   1445      330240    313.0
# 1350       APR-DRG   1165      330127    313.0
# 1660       APR-DRG   1301      330202    313.0
# 1970       APR-DRG   1172      330080    313.0
# 2280       APR-DRG   1454      330199    313.0
# 15569      APR-DRG   1186      330385    313.0
# 15879      APR-DRG   1692      330396    313.0
# 16249       MS-DRG   1309      330397    313.0
# 16740  MS-DRG V.35   1286      330233    313.0
# 17340  MS-DRG V.35   1305      330194    313.0
# 18011  MS-DRG V.35   1463      330214    313.0
# 18644  MS-DRG V.35   1738      330028    313.0
# 19144  MS-DRG V.36   1628      330193    313.0
# 19666  MS-DRG V.36   1629      330014    313.0
# 20301  MS-DRG V.36   1169      330059    313.0
# 21055  MS-DRG V.36   1456      330024    313.0
# 21766  MS-DRG V.36   1466      330046    313.0
# 22444  MS-DRG V.36   1306      330236    313.0
# 23174  MS-DRG V.36   1458      330101    313.0
# 23906  MS-DRG V.36   1637      330055    313.0
# 24580  MS-DRG V.36   1633      330231    313.0
# 25171  MS-DRG V.36   1320      330350    313.0
#
#                                    description       charges
# 189              KNEE/LWR LIMB PROC EXCPT FOOT  83364.026250
# 420    KNEE & LOWER LEG PROCEDURES EXCEPT FOOT  59345.150000
# 730    KNEE & LOWER LEG PROCEDURES EXCEPT FOOT  59345.150000
# 1040   KNEE & LOWER LEG PROCEDURES EXCEPT FOOT  59345.150000
# 1350   KNEE & LOWER LEG PROCEDURES EXCEPT FOOT  59345.150000
# 1660   KNEE & LOWER LEG PROCEDURES EXCEPT FOOT  59345.150000
# 1970   KNEE & LOWER LEG PROCEDURES EXCEPT FOOT  59345.150000
# 2280   KNEE & LOWER LEG PROCEDURES EXCEPT FOOT  59345.150000
# 15569  KNEE & LOWER LEG PROCEDURES EXCEPT FOOT  59345.150000
# 15879  KNEE & LOWER LEG PROCEDURES EXCEPT FOOT  59345.150000
# 16249                               CHEST PAIN  23961.370000
# 16740                               CHEST PAIN  12528.000000
# 17340                               CHEST PAIN  28270.563600
# 18011                               CHEST PAIN  35357.320000
# 18644                               CHEST PAIN  30699.560000
# 19144                            CHEST PAIN MS  11460.960000
# 19666                            CHEST PAIN MS   9341.550000
# 20301                               CHEST PAIN  30807.000000
# 21055                               CHEST PAIN  18248.000000
# 21766                               CHEST PAIN  35978.600000
# 22444                                      NaN  17363.388792
# 23174                                      NaN  30846.979296
# 23906                                      NaN  21603.361324
# 24580                               CHEST PAIN  35869.000000
# 25171                               CHEST PAIN   9821.959459

# %%
# Reading in the hospital data 
hospFeat = pd.read_json("https://data.cms.gov/resource/8rp3-rzmi.json?state_code=NY")
hospFeat.head()
# Out:
#    accounts_payable  accounts_receivable  allowable_dsh_percentage  buildings  \
# 0               NaN                  NaN                       NaN        NaN
# 1               NaN                  NaN                       NaN        NaN
# 2               NaN                  NaN                       NaN        NaN
# 3               NaN                  NaN                       NaN        NaN
# 4               NaN                  NaN                       NaN        NaN
#
#    cash_on_hand_and_in_banks ccn_facility_type        city  \
# 0                        NaN                PH  ORANGEBURG
# 1                        NaN                PH   ROCHESTER
# 2                        NaN                PH       UTICA
# 3                        NaN                PH   DIX HILLS
# 4                        NaN               STH   ROCHESTER
#
#    combined_outpatient_inpatient  contract_labor  cost_of_charity_care  \
# 0                     22147704.0             NaN                   NaN
# 1                      1939591.0             NaN                   NaN
# 2                      6125975.0             NaN                   NaN
# 3                            NaN             NaN                   NaN
# 4                            NaN             NaN                   NaN
#
#       ...      total_salaries_adjusted  total_salaries_from_worksheet  \
# 0     ...                   93088364.0                     93088364.0
# 1     ...                   34442946.0                     34442946.0
# 2     ...                   19373691.0                     19373691.0
# 3     ...                          NaN                            NaN
# 4     ...                          NaN                            NaN
#
#   total_unreimbursed_and  type_of_control  unsecured_loans  \
# 0             -3912103.0               10              NaN
# 1             -6429628.0               10              NaN
# 2                    NaN               10              NaN
# 3                    NaN               10              NaN
# 4                    NaN                5              NaN
#
#    wage_related_costs_core  wage_related_costs_for_interns  \
# 0               49192404.0                             NaN
# 1               18333880.0                             NaN
# 2               10361050.0                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
#
#    wage_related_costs_for_part wage_related_costs_rhc_fqhc    zip_code
# 0                          NaN                         NaN  10962-1196
# 1                          NaN                         NaN  14620-3965
# 2                          NaN                         NaN  13502-3803
# 3                          NaN                         NaN  11746-5861
# 4                          NaN                         NaN  14620-4629
#
# [5 rows x 118 columns]

# %%
hospFeat.dtypes
# Out:
# accounts_payable                    float64
# accounts_receivable                 float64
# allowable_dsh_percentage            float64
# buildings                           float64
# cash_on_hand_and_in_banks           float64
# ccn_facility_type                    object
# city                                 object
# combined_outpatient_inpatient       float64
# contract_labor                      float64
# cost_of_charity_care                float64
# cost_of_uncompensated_care          float64
# cost_to_charge_ratio                float64
# county                               object
# deferred_income                     float64
# depreciation_cost                   float64
# disproporationate_share             float64
# drg_amounts_after_october           float64
# drg_amounts_before_october          float64
# fiscal_year_begin_date               object
# fiscal_year_end_date                 object
# fixed_equipment                     float64
# fte_employees_on_payroll            float64
# general_fund_balance                float64
# gross_revenue                       float64
# health_information_technology       float64
# hospital_name                        object
# hospital_number_of_beds_for         float64
# hospital_total_bed_days             float64
# hospital_total_days_title_1         float64
# hospital_total_days_title_2         float64
#                                      ...
# total_days_title_xviii              float64
# total_days_title_xviii_total        float64
# total_days_v_xviii_xix_unknown      float64
# total_days_v_xviii_xix_unknown_1    float64
# total_discharges_title_xix          float64
# total_discharges_title_xix_1        float64
# total_discharges_title_xviii        float64
# total_discharges_title_xviii_1      float64
# total_discharges_v_xviii            float64
# total_discharges_v_xviii_1          float64
# total_fixed_assets                  float64
# total_fund_balances                 float64
# total_ime_payment                   float64
# total_income                        float64
# total_liabilities                   float64
# total_liabilities_and_fund          float64
# total_long_term_liabilities         float64
# total_other_assets                  float64
# total_other_expenses                float64
# total_other_income                  float64
# total_salaries_adjusted             float64
# total_salaries_from_worksheet       float64
# total_unreimbursed_and              float64
# type_of_control                       int64
# unsecured_loans                     float64
# wage_related_costs_core             float64
# wage_related_costs_for_interns      float64
# wage_related_costs_for_part         float64
# wage_related_costs_rhc_fqhc         float64
# zip_code                             object
# dtype: object

# %% [markdown]
#  HOSPITAL FEATURES
# - Provider CNN (same as provider id)
# - Type of Control (type of hospital eg: nonprofit/ gov)
# - Number of beds (only for lodging patients in acute, long term stay)
# - Total Days (V + XVIII + XIX + Unknown) - Total number of inpatient days for all classes of patients for each component
#
# COST FEATURES
# - Cost of Charity Care (cost of free, essential medical services rendered for ppl who can't pay)
# - Total Bad Debt Expense (cost of hosp services expected to not be paid, does not include doctor & other professional fee)
# - Total Costs (total hospital cost)
# - DRG Amounts Other Than Outlier Payments (DRG payment paid for Prospective Payment System (PPS) discharges)
# - Total IME payment (additional amt a teaching hospital 'earns' in addition to each Medicare case)
# - Disproporationate Share Adjustment (percentage add-on to the DRG payment, additional compensation for treating low income)
# - Net Patient Revenue (net income earned for each patient seen)
# - Net Revenue from Medicaid (inclusive of DSH & IME revenue)
# - Medicaid Charges (total revenue from Medicaid)
# - Net Revenue from Stand-Alone SCHIP (SCHIP = The State Children’s Health Insurance Program, for low income kids)
# - Stand-Alone SCHIP Charges (Total revenue from The State Children’s Health Insurance Program)
